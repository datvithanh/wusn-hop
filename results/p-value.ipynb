# # Friedman test

# %%
single_hop_data = [[float(tmp1) for tmp1 in tmp.split('\t')] for tmp in single_hop_data.split('\n')]

# %%
ga, pso, de, mt2, mt31, mt13, mt6 = zip(*single_hop_data)

# %%
stats.friedmanchisquare(*[ga, pso, de, mt6])
# Out:
# FriedmanchisquareResult(statistic=38.601769911504334, pvalue=2.107747993492999e-08)

# %%
multi_hop_data = [[float(tmp1) for tmp1 in tmp.split('\t')] for tmp in multi_hop_data.split('\n')]

# %%
gam, psom, dem, mt2m, mt31m, mt13m, mt6m = zip(*multi_hop_data)

# %%
stats.friedmanchisquare(*[gam, psom, dem, mt6m])
# Out:
# FriedmanchisquareResult(statistic=99.76800000000003, pvalue=1.7433282565865083e-21)

# %%
print(np.mean(ranks, axis=1))
# Out:
# [3.42 3.66 3.3  3.36 1.26]

# %%
arg_vals = []
for i in np.array([ga, pso, de, mt6]).T:
    ord_ = [(tmp2, tmp1) for tmp1, tmp2 in enumerate(i)]
    arg_val = [0] * 4
    ord_ = sorted(ord_, key=lambda x: x[0])
    arg_val[ord_[0][1]] = 1
    current = 1
    for idx, (val, arg) in enumerate(ord_):
        if idx == 0:
            continue
        if val == ord_[idx-1][0]:
            arg_val[arg] = current
            continue
        else:
            current += 1
            arg_val[arg] = current
    if current == 1:
        continue
    arg_vals.append(arg_val)
    
np.mean(arg_vals, axis=0)
# Out:
# array([2.92, 2.2 , 2.44, 1.08])

# %%
arg_vals = []
for i in np.array([gam, psom, dem, mt6m]).T:
    ord_ = [(tmp2, tmp1) for tmp1, tmp2 in enumerate(i)]
    arg_val = [0] * 4
    ord_ = sorted(ord_, key=lambda x: x[0])
    arg_val[ord_[0][1]] = 1
#     print(ord_)
    
    current = 1
    for idx, (val, arg) in enumerate(ord_):
        if idx == 0:
            continue
        if val == ord_[idx-1][0]:
            arg_val[arg] = current
            continue
        else:
            current += 1
            arg_val[arg] = current
    if current == 1:
        continue
    arg_vals.append(arg_val)
np.mean(arg_vals, axis=0)
# Out:
# array([2.6 , 3.54, 2.82, 1.04])

# %% [markdown]
# # sp.posthoc_conover_friedman(np.array([single, mt2, mt31, mt13, mt6]).T)

# %%
import scikit_posthocs as sp

# %%
sp.posthoc_conover_friedman(np.array([ga, pso, de, mt6]).T)
# Out:
#               0         1         2             3
# 0  1.000000e+00  0.004558  0.039465  1.209993e-08
# 1  4.558339e-03  1.000000  0.419638  1.558362e-03
# 2  3.946512e-02  0.419638  1.000000  9.259376e-05
# 3  1.209993e-08  0.001558  0.000093  1.000000e+00

# %%
sp.posthoc_conover_friedman(np.array([gam, psom, dem, mt6m]).T)
# Out:
#               0             1             2             3
# 0  1.000000e+00  3.886809e-04  3.967678e-01  1.288581e-08
# 1  3.886809e-04  1.000000e+00  6.121027e-03  2.159718e-17
# 2  3.967678e-01  6.121027e-03  1.000000e+00  1.634342e-10
# 3  1.288581e-08  2.159718e-17  1.634342e-10  1.000000e+00

# %%
3.886809e-04*100
# Out:
# 0.03886809

# %%
1.558362e-03*100
# Out:
# 0.1558362
