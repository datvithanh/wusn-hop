# %%
import os
import numpy as np

hop_data = {}

for fn in os.listdir('hop'):
    with open(os.path.join('hop', fn)) as f:
        lines = [tmp.replace('\n', '') for tmp in f.readlines()]
        hop_file = lines[0]
        res = float(lines[-1].split('\t')[-1])
        if hop_file not in hop_data.keys():
            hop_data[hop_file] = {fn: res}
        else:
            hop_data[hop_file][fn] = res
        
layer_data = {}

for fn in os.listdir('layer'):
    with open(os.path.join('layer', fn)) as f:
        lines = [tmp.replace('\n', '') for tmp in f.readlines()]
        hop_file = lines[0]
        res = float(lines[-1].split('\t')[-1])
        if hop_file not in layer_data.keys():
            layer_data[hop_file] = {fn: res}
        else:
            layer_data[hop_file][fn] = res
print(len(hop_data), len(layer_data))
# Out:
# 120 60

# %%
hop_mfea = {}
layer_mfea = {}

for fn in os.listdir('mfea'):
    with open(os.path.join('mfea', fn)) as f:
        lines = [tmp.replace('\n', '') for tmp in f.readlines()]
        hop_file, layer_file = lines[0].split(' ')
        res_hop = float(lines[-2].split('\t')[-1])
        res_layer = float(lines[-1].split('\t')[-1])
        if hop_file in hop_mfea.keys():
            hop_mfea[hop_file][fn] = res_hop
        else:
            hop_mfea[hop_file] = {fn: res_hop}
        if layer_file in layer_mfea.keys():
            layer_mfea[layer_file][fn] = res_layer
        else:
            layer_mfea[layer_file] = {fn: res_layer}

# %%
for i in sorted(layer_mfea.keys()):
    print(f'{i} {min(layer_data[i].values())} {min(layer_mfea[i].values())}')
    
for i in sorted(layer_mfea.keys()):
    print(f'{i} {min(layer_data[i].values())} {min(layer_mfea[i].values())}')
# Out:
# ga-dem10_r25_1.json 0.0010006225093249054 0.001000591521798013
# ga-dem10_r50_1.json 0.0010019365723787758 0.0010019365723787758
# ga-dem1_r25_1.json 0.0012006122670802865 0.0010009910609612893
# ga-dem1_r50_1.json 0.0014011252476113594 0.0012011506963858147
# ga-dem2_r25_1.json 0.001200942845510368 0.0012006467354327686
# ga-dem2_r50_1.json 0.0012017372192277382 0.0012005820532899971
# ga-dem3_r25_1.json inf 0.0010008920787976012
# ga-dem3_r50_1.json 0.001201444106686662 0.0012008674049973796
# ga-dem4_r25_1.json 0.0010009601668947007 0.001000800239921848
# ga-dem4_r50_1.json 0.0014014822226081434 0.0014014822226081434
# ga-dem5_r25_1.json 0.0016005984993507061 0.001400598499350706
# ga-dem5_r50_1.json 0.0012008142725377382 0.0012008142725377382
# ga-dem6_r25_1.json 0.0012007881852666089 0.0010009093702771981
# ga-dem6_r50_1.json 0.0012018026637000074 0.0012012881386273579
# ga-dem7_r25_1.json 0.001400651901998931 0.0012006196334707073
# ga-dem7_r50_1.json 0.0014016441621735377 0.0012016441621735376
# ga-dem8_r25_1.json 0.0012007934661042784 0.0010008835531231648
# ga-dem8_r50_1.json 0.0014012329273885296 0.0012014818533208449
# ga-dem9_r25_1.json 0.0010009321199288361 0.0010009321199288361
# ga-dem9_r50_1.json 0.0016005808804120548 0.0016005808804120548
# no-dem10_r25_1.json 0.0016008762209051674 0.0016008762209051674
# no-dem10_r50_1.json 0.0010019534432579612 0.0010012680551225663
# no-dem1_r25_1.json 0.0010009542877600106 0.0010009542877600106
# no-dem1_r50_1.json 0.0012009952913132876 0.0012009952913132876
# no-dem2_r25_1.json 0.0010008906514811986 0.0010008312062156483
# no-dem2_r50_1.json 0.0012010784976906781 0.0010015561823208652
# no-dem3_r25_1.json 0.0010008548221187015 0.0010005944262845936
# no-dem3_r50_1.json 0.0012006154665749474 0.001001001606957261
# no-dem4_r25_1.json 0.0012008319166200202 0.0012006046181603869
# no-dem4_r50_1.json 0.001001948092455175 0.0010018655933366582
# no-dem5_r25_1.json 0.0012009862411262512 0.0012009862411262512
# no-dem5_r50_1.json 0.0012014129810566947 0.0012014129810566947
# no-dem6_r25_1.json 0.001800845181243491 0.001800845181243491
# no-dem6_r50_1.json 0.0012009615011215177 0.0012007731262049853
# no-dem7_r25_1.json 0.0016006898422779553 0.0012009694261749964
# no-dem7_r50_1.json 0.0012010214509663303 0.0010019699236979
# no-dem8_r25_1.json 0.0010008003864616893 0.0010007150776330821
# no-dem8_r50_1.json 0.0012011765891583857 0.0010013038891692895
# no-dem9_r25_1.json 0.0018009961377042159 0.0018009961377042159
# no-dem9_r50_1.json 0.0014011880903988419 0.0014011880903988419
# uu-dem10_r25_1.json 0.0012004910677552371 0.001000766958081109
# uu-dem10_r50_1.json 0.0010016860651899072 0.0010014633695123879
# uu-dem1_r25_1.json 0.0010009901240991765 0.0010009528093151714
# uu-dem1_r50_1.json 0.0010019723503510753 0.0010017770740286603
# uu-dem2_r25_1.json 0.0010008664479069325 0.00100065172177382
# uu-dem2_r50_1.json 0.0014010627657681288 0.0014010627657681288
# uu-dem3_r25_1.json 0.0012006874106545037 0.001000867357113418
# uu-dem3_r50_1.json 0.001201102761006548 0.0012006489590311873
# uu-dem4_r25_1.json inf 0.0012009818638383809
# uu-dem4_r50_1.json 0.0010019711814676106 0.0010019711814676106
# uu-dem5_r25_1.json 0.0010008655555208891 0.0010008655555208891
# uu-dem5_r50_1.json 0.0010018597515090437 0.0010018597515090437
# uu-dem6_r25_1.json 0.001200799769387539 0.0012005767807216627
# uu-dem6_r50_1.json 0.0012013047868054073 0.0012007562686219388
# uu-dem7_r25_1.json 0.0012008250713917412 0.0012008250713917412
# uu-dem7_r50_1.json 0.0010019281925783352 0.0010013565383128788
# uu-dem8_r25_1.json 0.0012008623385687497 0.0010009220251219356
# uu-dem8_r50_1.json 0.0012018383257237468 0.0012018383257237468
# uu-dem9_r25_1.json 0.0010009710514460703 0.0010009710514460703
# uu-dem9_r50_1.json 0.0018013326011548307 0.0018013326011548307

# %%
regen_layer = []
regen_hop = []
def mean_woinf(li):
    li = [tmp for tmp in li if tmp < 10]
    return np.mean(li)

x = []
for i in sorted(layer_mfea.keys()):
    min_obj_mfea = min(layer_mfea[i].values())
    for pas, obj in layer_data[i].items():
        if obj < min_obj_mfea: 
            x.append(pas)
#             print(pas, obj, min_obj_mfea)
print('-----')
for i in sorted(hop_mfea.keys()):
    min_obj_mfea = min(hop_mfea[i].values())
    for pas, obj in hop_data[i].items():
        if obj < min_obj_mfea:
            x.append(pas)
            print(pas, obj, min_obj_mfea)
#     if hop_data[i] < hop_mfea[i]:
# len(set([tmp[:-6] for tmp in x]))
for i in x:
    print(i)
# Out:
# -----
# ga-dem1_r25_1_40_4.txt 0.0030005540919456767 0.0034008967337463484
# ga-dem2_r50_1_40_3.txt 0.0020012222543753988 0.0026005820532899976
# ga-dem4_r25_1_40_8.txt 0.0026008025419476393 0.0028009692437085815
# ga-dem5_r50_1_40_6.txt 0.0026016238220647296 0.0030013499053853266
# ga-dem5_r50_1_40_2.txt 0.0028018362268133158 0.0030013499053853266
# ga-dem6_r50_1_40_4.txt 0.002801646689153388 0.0032013673699276255
# ga-dem6_r50_1_40_3.txt 0.0028014073873744456 0.0032013673699276255
# no-dem4_r25_1_0_6.txt 0.0014004229289465966 0.0014008319166200203
# no-dem8_r25_1_40_3.txt 0.0028009783275911755 0.0032005468752132568
# no-dem8_r50_1_40_0.txt 0.00280188547562116 0.003001672429102345
# no-dem8_r50_1_40_7.txt 0.002401886077991895 0.003001672429102345
# uu-dem7_r25_1_40_6.txt 0.002800972349207548 0.003000992035714157
# uu-dem8_r50_1_40_9.txt 0.003001884401530281 0.0032018814423813184
# uu-dem9_r25_1_40_9.txt 0.002600758100534695 0.0030007288800966195
# uu-dem9_r25_1_40_0.txt 0.0028009473712231445 0.0030007288800966195
# uu-dem9_r50_1_40_3.txt 0.003401634999842622 0.0034018547242941
# ga-dem1_r25_1_40_4.txt
# ga-dem2_r50_1_40_3.txt
# ga-dem4_r25_1_40_8.txt
# ga-dem5_r50_1_40_6.txt
# ga-dem5_r50_1_40_2.txt
# ga-dem6_r50_1_40_4.txt
# ga-dem6_r50_1_40_3.txt
# no-dem4_r25_1_0_6.txt
# no-dem8_r25_1_40_3.txt
# no-dem8_r50_1_40_0.txt
# no-dem8_r50_1_40_7.txt
# uu-dem7_r25_1_40_6.txt
# uu-dem8_r50_1_40_9.txt
# uu-dem9_r25_1_40_9.txt
# uu-dem9_r25_1_40_0.txt
# uu-dem9_r50_1_40_3.txt

# %%
asd = []
for i in sorted(hop_mfea.keys()):
    min_obj_mfea = max(hop_mfea[i].values())
#     print(min_obj_mfea)
    for pas, obj in hop_mfea[i].items():
        if obj > 10:
            asd.append(pas)
            print(pas)
    
for i in sorted(layer_mfea.keys()):
    min_obj_mfea = max(layer_mfea[i].values())
    for pas, obj in layer_mfea[i].items():
        if obj > 10:
            asd.append(pas)
            print(pas)
# Out:
# ga-dem10_r25_1_40_9.txt
# ga-dem10_r25_1_40_3.txt
# ga-dem10_r25_1_40_6.txt
# ga-dem10_r50_1_40_5.txt
# uu-dem1_r25_1_40_9.txt
# ga-dem3_r25_1_40_2.txt
# ga-dem3_r25_1_40_4.txt
# ga-dem3_r25_1_0_8.txt
# ga-dem3_r25_1_0_9.txt
# ga-dem3_r25_1_40_5.txt
# ga-dem3_r25_1_40_6.txt
# ga-dem3_r25_1_40_8.txt
# ga-dem3_r25_1_0_1.txt
# ga-dem3_r25_1_0_0.txt
# ga-dem4_r25_1_40_1.txt
# ga-dem4_r25_1_40_0.txt
# uu-dem4_r25_1_40_8.txt
# uu-dem4_r25_1_0_9.txt
# uu-dem4_r25_1_40_9.txt
# uu-dem4_r25_1_40_4.txt
# uu-dem4_r25_1_0_7.txt
# uu-dem4_r25_1_0_6.txt
# uu-dem4_r25_1_40_6.txt
# uu-dem4_r25_1_40_2.txt
# uu-dem4_r25_1_40_1.txt
# uu-dem4_r25_1_40_0.txt

# %%
set([tmp[:-6] for tmp in asd])
# Out:
# {'ga-dem10_r25_1_40',
#  'ga-dem10_r50_1_40',
#  'ga-dem3_r25_1_0',
#  'ga-dem3_r25_1_40',
#  'ga-dem4_r25_1_40',
#  'uu-dem1_r25_1_40',
#  'uu-dem4_r25_1_0',
#  'uu-dem4_r25_1_40'}

# %%
das = []
for i in layer_data.keys():
    for pas, obj in layer_data[i].items():
        if obj > 10:
            das.append(pas)
            print(pas)
            
for i in hop_data.keys():
    for pas, obj in hop_data[i].items():
        if obj > 10:
            das.append(pas)
            print(pas)
# Out:
# ga-dem5_r25_1_2.txt
# ga-dem5_r25_1_3.txt
# ga-dem5_r25_1_7.txt
# ga-dem5_r25_1_4.txt
# ga-dem5_r25_1_8.txt
# ga-dem5_r25_1_9.txt
# no-dem4_r25_1_5.txt
# no-dem4_r25_1_1.txt
# no-dem4_r25_1_3.txt
# no-dem4_r25_1_9.txt
# uu-dem4_r50_1_9.txt
# uu-dem4_r50_1_8.txt
# uu-dem4_r50_1_0.txt
# uu-dem4_r50_1_2.txt
# uu-dem4_r50_1_6.txt
# uu-dem2_r25_1_3.txt
# uu-dem2_r25_1_0.txt
# uu-dem2_r25_1_5.txt
# uu-dem2_r25_1_4.txt
# uu-dem2_r25_1_6.txt
# uu-dem2_r25_1_9.txt
# uu-dem3_r50_1_6.txt
# uu-dem3_r50_1_7.txt
# uu-dem3_r50_1_3.txt
# uu-dem3_r50_1_0.txt
# uu-dem3_r50_1_1.txt
# uu-dem7_r25_1_6.txt
# ga-dem7_r25_1_9.txt
# ga-dem7_r25_1_3.txt
# ga-dem7_r25_1_6.txt
# ga-dem7_r25_1_4.txt
# no-dem9_r50_1_6.txt
# no-dem9_r50_1_4.txt
# no-dem9_r50_1_1.txt
# no-dem9_r50_1_2.txt
# no-dem3_r25_1_1.txt
# no-dem3_r25_1_4.txt
# no-dem3_r25_1_6.txt
# no-dem2_r50_1_4.txt
# no-dem2_r50_1_6.txt
# ga-dem2_r25_1_9.txt
# ga-dem2_r25_1_3.txt
# ga-dem7_r50_1_6.txt
# uu-dem1_r25_1_5.txt
# uu-dem1_r25_1_1.txt
# ga-dem1_r25_1_3.txt
# ga-dem1_r25_1_4.txt
# uu-dem9_r50_1_1.txt
# uu-dem9_r50_1_7.txt
# uu-dem8_r25_1_4.txt
# uu-dem8_r25_1_5.txt
# uu-dem8_r25_1_3.txt
# uu-dem8_r25_1_1.txt
# uu-dem8_r25_1_8.txt
# uu-dem8_r25_1_9.txt
# no-dem10_r50_1_7.txt
# no-dem10_r50_1_8.txt
# no-dem10_r50_1_9.txt
# ga-dem10_r50_1_4.txt
# ga-dem10_r50_1_5.txt
# ga-dem10_r50_1_1.txt
# ga-dem10_r50_1_2.txt
# ga-dem10_r50_1_3.txt
# uu-dem4_r25_1_2.txt
# uu-dem4_r25_1_3.txt
# uu-dem4_r25_1_1.txt
# uu-dem4_r25_1_0.txt
# uu-dem4_r25_1_4.txt
# uu-dem4_r25_1_5.txt
# uu-dem4_r25_1_7.txt
# uu-dem4_r25_1_6.txt
# uu-dem4_r25_1_8.txt
# uu-dem4_r25_1_9.txt
# ga-dem3_r25_1_0.txt
# ga-dem3_r25_1_1.txt
# ga-dem3_r25_1_3.txt
# ga-dem3_r25_1_2.txt
# ga-dem3_r25_1_6.txt
# ga-dem3_r25_1_7.txt
# ga-dem3_r25_1_5.txt
# ga-dem3_r25_1_4.txt
# ga-dem3_r25_1_9.txt
# ga-dem3_r25_1_8.txt
# uu-dem2_r50_1_7.txt
# uu-dem2_r50_1_4.txt
# uu-dem2_r50_1_5.txt
# no-dem2_r25_1_7.txt
# no-dem2_r25_1_4.txt
# no-dem2_r25_1_8.txt
# uu-dem6_r25_1_8.txt
# uu-dem6_r25_1_9.txt
# uu-dem6_r25_1_2.txt
# uu-dem6_r25_1_1.txt
# uu-dem6_r25_1_0.txt
# uu-dem6_r25_1_5.txt
# uu-dem6_r25_1_7.txt
# uu-dem6_r25_1_6.txt
# ga-dem8_r25_1_9.txt
# ga-dem8_r25_1_8.txt
# ga-dem8_r25_1_3.txt
# ga-dem8_r25_1_2.txt
# ga-dem8_r25_1_1.txt
# ga-dem8_r25_1_5.txt
# ga-dem8_r25_1_4.txt
# ga-dem8_r25_1_6.txt
# ga-dem8_r25_1_7.txt
# no-dem8_r50_1_2.txt
# no-dem8_r50_1_3.txt
# no-dem8_r50_1_4.txt
# no-dem8_r50_1_6.txt
# no-dem5_r25_1_8.txt
# no-dem5_r25_1_9.txt
# no-dem5_r25_1_1.txt
# no-dem5_r25_1_0.txt
# no-dem5_r25_1_5.txt
# no-dem5_r25_1_7.txt
# uu-dem3_r25_1_4.txt
# uu-dem7_r50_1_1.txt
# no-dem4_r50_1_7.txt
# no-dem4_r50_1_0.txt
# ga-dem4_r25_1_9.txt
# ga-dem4_r25_1_8.txt
# ga-dem4_r25_1_4.txt
# ga-dem4_r25_1_6.txt
# ga-dem4_r25_1_3.txt
# ga-dem4_r25_1_2.txt
# ga-dem4_r25_1_0.txt
# ga-dem4_r25_1_1.txt
# ga-dem10_r50_1_40_2.txt
# ga-dem10_r50_1_40_3.txt
# ga-dem10_r50_1_40_0.txt
# ga-dem10_r50_1_40_4.txt
# ga-dem10_r50_1_40_5.txt
# ga-dem10_r50_1_40_7.txt
# ga-dem10_r50_1_40_9.txt
# uu-dem1_r25_1_40_8.txt
# uu-dem1_r25_1_40_2.txt
# uu-dem1_r25_1_40_3.txt
# uu-dem1_r25_1_40_1.txt
# uu-dem1_r25_1_40_5.txt
# uu-dem1_r25_1_40_6.txt
# ga-dem10_r25_1_40_8.txt
# ga-dem10_r25_1_40_9.txt
# ga-dem10_r25_1_40_2.txt
# ga-dem10_r25_1_40_3.txt
# ga-dem10_r25_1_40_1.txt
# ga-dem10_r25_1_40_4.txt
# ga-dem10_r25_1_40_7.txt
# ga-dem10_r25_1_40_6.txt
# no-dem5_r25_1_40_9.txt
# no-dem5_r25_1_40_7.txt
# no-dem5_r25_1_40_0.txt
# uu-dem5_r25_1_40_0.txt
# ga-dem3_r25_1_40_1.txt
# ga-dem3_r25_1_40_4.txt
# ga-dem3_r25_1_40_6.txt
# uu-dem10_r50_1_40_9.txt
# uu-dem10_r50_1_40_8.txt
# uu-dem10_r50_1_40_1.txt
# uu-dem10_r50_1_40_3.txt
# uu-dem10_r50_1_40_6.txt
# uu-dem10_r50_1_40_7.txt
# uu-dem10_r50_1_40_5.txt
# uu-dem10_r50_1_40_4.txt
# ga-dem4_r25_1_40_0.txt
# ga-dem4_r25_1_40_7.txt
# ga-dem5_r25_1_40_6.txt
# no-dem8_r25_1_40_9.txt
# no-dem8_r25_1_40_1.txt
# no-dem8_r25_1_40_5.txt
# no-dem1_r25_1_40_8.txt
# no-dem1_r25_1_40_6.txt
# no-dem1_r25_1_40_4.txt

# %%
len(das)
# Out:
# 173
