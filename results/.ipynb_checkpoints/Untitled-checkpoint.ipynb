# %%
import os
import numpy as np

hop_data = {}

for fn in os.listdir('hop'):
    with open(os.path.join('hop', fn)) as f:
        lines = [tmp.replace('\n', '') for tmp in f.readlines()]
        hop_file = lines[0]
        res = float(lines[-1].split('\t')[-1])
        if hop_file not in hop_data.keys():
            hop_data[hop_file] = {fn: res}
        else:
            hop_data[hop_file][fn] = res
        
layer_data = {}

for fn in os.listdir('layer'):
    with open(os.path.join('layer', fn)) as f:
        lines = [tmp.replace('\n', '') for tmp in f.readlines()]
        hop_file = lines[0]
        res = float(lines[-1].split('\t')[-1])
        if hop_file not in layer_data.keys():
            layer_data[hop_file] = {fn: res}
        else:
            layer_data[hop_file][fn] = res
print(len(hop_data), len(layer_data))
# Out:
# 120 60

# %%
hop_mfea = {}
layer_mfea = {}

for fn in os.listdir('mfea'):
    with open(os.path.join('mfea', fn)) as f:
        lines = [tmp.replace('\n', '') for tmp in f.readlines()]
        hop_file, layer_file = lines[0].split(' ')
        res_hop = float(lines[-2].split('\t')[-1])
        res_layer = float(lines[-1].split('\t')[-1])
        if hop_file in hop_mfea.keys():
            hop_mfea[hop_file][fn] = res_hop
        else:
            hop_mfea[hop_file] = {fn: res_hop}
        if layer_file in layer_mfea.keys():
            layer_mfea[layer_file][fn] = res_layer
        else:
            layer_mfea[layer_file] = {fn: res_layer}

# %%
from statistics import stdev

for i in sorted(layer_mfea.keys()):
    ld = list(layer_data[i].values())
    lm = list(layer_mfea[i].values())
    print(f'{i} {min(ld)} {min(lm)} {np.mean(ld)} {np.mean(lm)} {stdev(ld)} {stdev(lm)}')
    
for i in sorted(hop_mfea.keys()):
    hd = list(hop_data[i].values())
    hm = list(hop_mfea[i].values())
    print(f'{i} {min(hd)} {min(hm)}')
# Out:
# ga-dem10_r25_1.json 0.0010006225093249054 0.001000591521798013 0.00114076134433823 0.001070715823783141
# ga-dem10_r50_1.json 0.0010019365723787758 0.0010019365723787758 0.0012017809129288158 0.0010617904383677438
# ga-dem1_r25_1.json 0.0010009910609612893 0.0010009910609612893 0.0012208353163047404 0.0011507373152417517
# ga-dem1_r50_1.json 0.0014011252476113594 0.0012011506963858147 0.001621348732090087 0.0014114818962527003
# ga-dem2_r25_1.json 0.001200942845510368 0.0012006467354327686 0.0015008719429506197 0.0013108551606545815
# ga-dem2_r50_1.json 0.0012017372192277382 0.0012005820532899971 0.0014415485756857707 0.0013113739332594391
# ga-dem3_r25_1.json 0.001000985094557834 0.0010008920787976012 0.0013207932844083506 0.0014708380600608087
# ga-dem3_r50_1.json 0.001201444106686662 0.0012008674049973796 0.0014015271291359527 0.0012712988690016709
# ga-dem4_r25_1.json 0.0010009601668947007 0.001000800239921848 0.001260817291289036 0.0011507900421628228
# ga-dem4_r50_1.json 0.0014014822226081434 0.0014014822226081434 0.0017812943148064436 0.001401503942187209
# ga-dem5_r25_1.json 0.001400598499350706 0.001400598499350706 0.0016807665909233994 0.0014806855766290436
# ga-dem5_r50_1.json 0.0012008142725377382 0.0012008142725377382 0.0015614227836157038 0.0012915965007514573
# uu-dem5_r25_1_40.json 0.002400926352543346 0.0024008859167863193
# uu-dem5_r50_1_0.json 0.001400523510521037 0.001400523510521037
# uu-dem5_r50_1_40.json 0.0030011726617558037 0.002801859751509044
# uu-dem6_r25_1_0.json 0.0014009311649478223 0.0014007816541354442
# uu-dem6_r25_1_40.json 0.0030008487686474013 0.0028007885119132104
# uu-dem6_r50_1_0.json 0.0016008993771303387 0.0012019149276945777
# uu-dem6_r50_1_40.json 0.0028019010771897063 0.00280162396313678
# uu-dem7_r25_1_0.json 0.0016006383365640637 0.0014008364563682007
# uu-dem7_r25_1_40.json 0.003000610808301122 0.003000992035714157
# uu-dem7_r50_1_0.json 0.0014010459361881843 0.0012019281925783353
# uu-dem7_r50_1_40.json 0.0026019844115592245 0.0026014015293712445
# uu-dem8_r25_1_0.json 0.0014009740242898181 0.001200979521928115
# uu-dem8_r25_1_40.json 0.0028009599883282938 0.0028009599883282938
# uu-dem8_r50_1_0.json 0.0016003882214124991 0.0014010495872311226
# uu-dem8_r50_1_40.json 0.0034007044939640576 0.0032018814423813184
# uu-dem9_r25_1_0.json 0.0014009041129436441 0.0014009041129436441
# uu-dem9_r25_1_40.json 0.003000723307365833 0.0030007288800966195
# uu-dem9_r50_1_0.json 0.001401277330897139 0.001401277330897139
# uu-dem9_r50_1_40.json 0.003601277330897139 0.0034018547242941

# %%
regen_layer = []
regen_hop = []
def mean_woinf(li):
    li = [tmp for tmp in li if tmp < 10]
    return np.mean(li)

x = []
for i in sorted(layer_mfea.keys()):
    min_obj_mfea = min(layer_mfea[i].values())
    for pas, obj in layer_data[i].items():
        if obj < min_obj_mfea: 
            x.append(pas)
#             print(pas, obj, min_obj_mfea)
print('-----')
for i in sorted(hop_mfea.keys()):
    min_obj_mfea = min(hop_mfea[i].values())
    for pas, obj in hop_data[i].items():
        if obj < min_obj_mfea:
            x.append(pas)
#             print(pas, obj, min_obj_mfea)
#     if hop_data[i] < hop_mfea[i]:
# len(set([tmp[:-6] for tmp in x]))
for i in x:
    print(i)
# Out:
# -----
# ga-dem10_r25_1_40_8.txt
# ga-dem10_r50_1_40_7.txt
# ga-dem5_r50_1_40_2.txt
# ga-dem6_r50_1_40_3.txt
# no-dem8_r50_1_40_7.txt
# uu-dem7_r25_1_40_6.txt
# uu-dem9_r25_1_40_9.txt

# %%
asd = []
for i in sorted(hop_mfea.keys()):
    min_obj_mfea = max(hop_mfea[i].values())
#     print(min_obj_mfea)
    for pas, obj in hop_mfea[i].items():
        if obj > 10:
            asd.append(pas)
            print(pas)
    
for i in sorted(layer_mfea.keys()):
    min_obj_mfea = max(layer_mfea[i].values())
    for pas, obj in layer_mfea[i].items():
        if obj > 10:
            asd.append(pas)
            print(pas)

# %%
set([tmp[:-6] for tmp in asd])
# Out:
# set()

# %%
das = []
for i in layer_data.keys():
    for pas, obj in layer_data[i].items():
        if obj > 10:
            das.append(pas)
            print(pas)
            
for i in hop_data.keys():
    for pas, obj in hop_data[i].items():
        if obj > 10:
            das.append(pas)
            print(pas)
