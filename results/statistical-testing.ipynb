# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Layer data

# %%
layer_data = {}

for fn in os.listdir('small/layer'):
    with open(os.path.join('small/layer', fn)) as f:
        lines = [tmp.replace('\n', '') for tmp in f.readlines()]
        hop_file = lines[0]
        res = float(lines[-1].split('\t')[-1])
        if res > 10:
            print(fn)
        if hop_file not in layer_data.keys():
            layer_data[hop_file] = {fn: res}
        else:
            layer_data[hop_file][fn] = res

# %%
layer_data.keys()
# Out:
# dict_keys(['uu-dem1_r25_1.json', 'uu-dem5_r25_1.json', 'uu-dem6_r25_1.json', 'uu-dem2_r25_1.json', 'uu-dem10_r25_1.json', 'uu-dem7_r25_1.json', 'uu-dem4_r25_1.json', 'uu-dem9_r25_1.json', 'uu-dem8_r25_1.json', 'uu-dem3_r25_1.json'])

# %%
for k in layer_data.keys():
    plt.hist(layer_data[k].values(), bins=20)
    plt.show()
    plt.clf()

# %% [markdown]
# # Hop data

# %%
hop_data = {}

for fn in os.listdir('small/hop'):
    with open(os.path.join('small/hop', fn)) as f:
        lines = [tmp.replace('\n', '') for tmp in f.readlines()]
        hop_file = lines[0]
        res = float(lines[-1].split('\t')[-1])
        if res > 10:
            print(fn)
        if hop_file not in hop_data.keys():
            hop_data[hop_file] = {fn: res}
        else:
            hop_data[hop_file][fn] = res

# %%
for k in hop_data.keys():
    plt.hist(hop_data[k].values(), bins=20)
    plt.show()
    plt.clf()
